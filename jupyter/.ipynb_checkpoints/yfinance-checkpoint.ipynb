# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf

# %%
tick = yf.Ticker("MSFT")
tick.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 163000,
# ...

# %%
#Input Date Range
startYear = 1999
startMonth = 12
startDay = 31
endYear = 2009
endMonth = 12
endDay = 31

#Format Range
startDate = str(startYear) + "-" + str(startMonth) + "-" + str(startDay)
endDate = str(endYear) + "-" + str(endMonth) + "-" + str(endDay)

#Input Holdings
stock1 = "AAPL"
stock2 = "MSFT"
stock3 = "SPY"
stock4 = "HD"

#Pulling Holdings Data
stock1Data = yf.download(stock1, start=startDate, end=endDate)
stock2Data = yf.download(stock2, start=startDate, end=endDate)
stock3Data = yf.download(stock3, start=startDate, end=endDate)
stock4Data = yf.download(stock4, start=startDate, end=endDate)

#Set to DataFrame
stock1Data = pd.DataFrame(stock1Data)
stock2Data = pd.DataFrame(stock2Data)
stock3Data = pd.DataFrame(stock3Data)
stock4Data = pd.DataFrame(stock4Data)

stock1StartPrice = pd.DataFrame()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
print(startDate)
print(endDate)
print(stock1)
print(stock1Data)
print(stock2Data)
print(stock3Data)
print(stock4Data)
# Out:
# 1999-12-31
# 2009-12-31
# AAPL
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 1999-12-31  0.901228  0.918527  0.888393  0.917969   0.789364  163811200
# 2000-01-03  0.936384  1.004464  0.907924  0.999442   0.859423  535796800
# 2000-01-04  0.966518  0.987723  0.903460  0.915179   0.786965  512377600
# 2000-01-05  0.926339  0.987165  0.919643  0.928571   0.798481  778321600
# 2000-01-06  0.947545  0.955357  0.848214  0.848214   0.729382  767972800
# ...              ...       ...       ...       ...        ...        ...
# 2009-12-23  7.185714  7.227857  7.171786  7.217857   6.206654  345525600
# 2009-12-24  7.269643  7.476786  7.262500  7.465714   6.419788  500889200
# 2009-12-28  7.561429  7.641071  7.486071  7.557500   6.498715  644565600
# 2009-12-29  7.593929  7.597143  7.454643  7.467857   6.421631  445205600
# 2009-12-30  7.458214  7.571429  7.439643  7.558571   6.499636  412084400
#
# [2515 rows x 6 columns]
# ...
